# %%
import tensorflow as tf
import numpy as np
import matplotlib.pylab as plt
import data
import importlib

import opreg
import data
importlib.reload(data)
# Out:
# <module 'data' from '/Users/rgpatel/sciml_tutorial/sciml_tensorflow_tutorial/exercises/data.py'>

# %% [markdown]
# # Exercise 2
#
# # Burgers equation using MOR-Physics
#
# Let's try to recover the viscous Burgers equation. This time using MOR-Physics
#
# \begin{aligned}
# \partial_t u + \partial_x u^2 = \nu \partial_x^2 u \\
# x \in [0,2\pi] \textrm{ (periodic) }
# \end{aligned}

# %%
#k is the wavenumber
x,t,u,k = data.get_ex6_2(10)
_,_,u_test,_ = data.get_ex6_2(1)
L = 2*np.pi
T = 1

# %%
plt.imshow(u_test[0],origin='lower',extent=[0,L,0,T])
plt.colorbar()
plt.xlabel('$x$')
plt.ylabel('$t$')
plt.figure()
plt.plot(x,u_test[0,::100].T)
plt.xlabel('x')
plt.ylabel('u')

print('data shape: ', u.shape)
# Out:
# data shape:  (1, 1001, 256)
