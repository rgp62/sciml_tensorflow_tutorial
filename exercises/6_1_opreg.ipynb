# %%
import tensorflow as tf
import numpy as np
import matplotlib.pylab as plt
import data
import importlib

import opreg
import data
importlib.reload(data)
# Out:
# <module 'data' from '/Users/rgpatel/sciml_tutorial/sciml_tensorflow_tutorial/exercises/data.py'>

# %% [markdown]
# # Exercise 1
#
# # Burgers operator using MOR-Physics
#
# Fit the Burgers operator on a periodic domain,
#
# \begin{equation}
# \partial_x u^2 = v
# \end{equation}
#
# given pairs of $u,v$

# %%
u,v = data.get_ex6_1(10)
u_test,v_test = data.get_ex6_1(1)

#plots of a sample of u and v
fig,ax = plt.subplots(1,2,figsize=(8,4))
ax[0].plot(u[0])
ax[0].set_title('$u$ sample')
ax[1].plot(v[0])
ax[1].set_title('$v$ sample')
ax[1].plot()
# Out:
# []
